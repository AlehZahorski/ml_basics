# %% [markdown]
# <a href="https://colab.research.google.com/github/AlehZahorski/ml_basics/blob/main/supervised/01_basics/01_preprocessing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import sklearn

sklearn.__version__
# Out:
# '1.6.1'

# %%
import pandas as pd

data = {
    'size': ['XL', 'L', 'M', 'L', 'M'],
    'color': ['red', 'green', 'blue', 'green', 'red'],
    'gender': ['female', 'male', 'male', 'female', 'female'],
    'price': [199.0, 89.0, 99.0, 129.0, 79.0],
    'weight': [500, 450, 300, 380, 410],
    'bought': ['yes', 'no', 'yes', 'no', 'yes']
}

df_raw = pd.DataFrame(data=data)
df_raw
# Out:
#   size  color  gender  price  weight bought
# 0   XL    red  female  199.0     500    yes
# 1    L  green    male   89.0     450     no
# 2    M   blue    male   99.0     300    yes
# 3    L  green  female  129.0     380     no
# 4    M    red  female   79.0     410    yes

# %%
df = df_raw.copy()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   size    5 non-null      object
#  1   color   5 non-null      object
#  2   gender  5 non-null      object
#  3   price   5 non-null      float64
#  4   weight  5 non-null      int64
#  5   bought  5 non-null      object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 372.0+ bytes

# %%
for col in ['size', 'color', 'gender', 'bought']:
    df[col] = df[col].astype('category')

df['weight'] = df['weight'].astype('float')

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   size    5 non-null      category
#  1   color   5 non-null      category
#  2   gender  5 non-null      category
#  3   price   5 non-null      float64
#  4   weight  5 non-null      float64
#  5   bought  5 non-null      category
# dtypes: category(4), float64(2)
# memory usage: 744.0 bytes

# %%
df.describe(include=['category']).T
# Out:
#        count unique     top freq
# size       5      3       L    2
# color      5      3   green    2
# gender     5      2  female    3
# bought     5      2     yes    3

# %%
df
# Out:
#   size  color  gender  price  weight bought
# 0   XL    red  female  199.0   500.0    yes
# 1    L  green    male   89.0   450.0     no
# 2    M   blue    male   99.0   300.0    yes
# 3    L  green  female  129.0   380.0     no
# 4    M    red  female   79.0   410.0    yes

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
le.fit(df['bought'])
le.transform(df['bought'])
# Out:
# array([1, 0, 1, 0, 1])

# %%
le.fit_transform(df['bought'])
# Out:
# array([1, 0, 1, 0, 1])

# %%
le.classes_
# Out:
# array(['no', 'yes'], dtype=object)

# %%
df['bought'] = le.fit_transform(df['bought'])
df
# Out:
#   size  color  gender  price  weight  bought
# 0   XL    red  female  199.0   500.0       1
# 1    L  green    male   89.0   450.0       0
# 2    M   blue    male   99.0   300.0       1
# 3    L  green  female  129.0   380.0       0
# 4    M    red  female   79.0   410.0       1

# %%
from sklearn.preprocessing import OneHotEncoder

encoder = OneHotEncoder(sparse_output=False)
encoder.fit(df[['size']])
encoder.transform(df[['size']])
# Out:
# array([[0., 0., 1.],
#        [1., 0., 0.],
#        [0., 1., 0.],
#        [1., 0., 0.],
#        [0., 1., 0.]])

# %%
encoder.categories_
# Out:
# [array(['L', 'M', 'XL'], dtype=object)]

# %%
encoder = OneHotEncoder(drop='first', sparse_output=False)
encoder.fit_transform(df[['size']])
# Out:
# array([[0., 1.],
#        [0., 0.],
#        [1., 0.],
#        [0., 0.],
#        [1., 0.]])

# %%
df
# Out:
#   size  color  gender  price  weight  bought
# 0   XL    red  female  199.0   500.0       1
# 1    L  green    male   89.0   450.0       0
# 2    M   blue    male   99.0   300.0       1
# 3    L  green  female  129.0   380.0       0
# 4    M    red  female   79.0   410.0       1

# %%
pd.get_dummies(data=df)
# Out:
#    price  weight  bought  ...  color_red  gender_female  gender_male
# 0  199.0   500.0       1  ...       True           True        False
# 1   89.0   450.0       0  ...      False          False         True
# 2   99.0   300.0       1  ...      False          False         True
# 3  129.0   380.0       0  ...      False           True        False
# 4   79.0   410.0       1  ...       True           True        False
#
# [5 rows x 11 columns]

# %%
pd.get_dummies(data=df, drop_first=True)
# Out:
#    price  weight  bought  size_M  size_XL  color_green  color_red  gender_male
# 0  199.0   500.0       1   False     True        False       True        False
# 1   89.0   450.0       0   False    False         True      False         True
# 2   99.0   300.0       1    True    False        False      False         True
# 3  129.0   380.0       0   False    False         True      False        False
# 4   79.0   410.0       1    True    False        False       True        False

# %%
pd.get_dummies(data=df, drop_first=True, prefix_sep='_')
# Out:
#    price  weight  bought  size_M  size_XL  color_green  color_red  gender_male
# 0  199.0   500.0       1   False     True        False       True        False
# 1   89.0   450.0       0   False    False         True      False         True
# 2   99.0   300.0       1    True    False        False      False         True
# 3  129.0   380.0       0   False    False         True      False        False
# 4   79.0   410.0       1    True    False        False       True        False

# %%
from sklearn.preprocessing import scale

scale(df['price'])
# Out:
# array([ 1.84506242, -0.69189841, -0.4612656 ,  0.2306328 , -0.92253121])

# %%
def standarizeNumber(x):
  return (x - x.mean()) / x.std()

standarizeNumber(df['price'])
# Out:
# 0    1.650274
# 1   -0.618853
# 2   -0.412568
# 3    0.206284
# 4   -0.825137
# Name: price, dtype: float64

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
scaler.fit_transform(df[['price']])
# Out:
# array([[ 1.84506242],
#        [-0.69189841],
#        [-0.4612656 ],
#        [ 0.2306328 ],
#        [-0.92253121]])

# %%
scaler = StandardScaler()
df[['price', 'weight']] = scaler.fit_transform(df[['price','weight']])
df
# Out:
#   size  color  gender     price    weight  bought
# 0   XL    red  female  1.845062  1.366002       1
# 1    L  green    male -0.691898  0.623610       0
# 2    M   blue    male -0.461266 -1.603567       1
# 3    L  green  female  0.230633 -0.415740       0
# 4    M    red  female -0.922531  0.029696       1

# %%
df = df_raw.copy()
df
# Out:
#   size  color  gender  price  weight bought
# 0   XL    red  female  199.0     500    yes
# 1    L  green    male   89.0     450     no
# 2    M   blue    male   99.0     300    yes
# 3    L  green  female  129.0     380     no
# 4    M    red  female   79.0     410    yes

# %%
le = LabelEncoder()
df['bought'] = le.fit_transform(df['bought'])

scaler = StandardScaler()
df[['price','weight']] = scaler.fit_transform(df[['price','weight']])

df = pd.get_dummies(data=df, drop_first=True)
df
# Out:
#       price    weight  bought  ...  color_green  color_red  gender_male
# 0  1.845062  1.366002       1  ...        False       True        False
# 1 -0.691898  0.623610       0  ...         True      False         True
# 2 -0.461266 -1.603567       1  ...        False      False         True
# 3  0.230633 -0.415740       0  ...         True      False        False
# 4 -0.922531  0.029696       1  ...        False       True        False
#
# [5 rows x 8 columns]
